# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import h5py
import numpy as np
from activ.analytics import heatmap
from activ.clustering import UmapClusteringResults
from os.path import dirname, join
from matplotlib.backends.backend_pdf import PdfPages

# path = "../results/sweep_u2-10_c2-50_i50_raw-oc-cluster_uoinmf-bm-predict/umap_clustering_sweep.h5"
path = "../results/mahalanobis_output/umap_cluster_uoinmf-mahalanobis.h5"
# pdf = PdfPages(join(dirname(path), 'umap_clustering_sweep_mahalanobis_summary.pdf'))

# %%
help(UmapClusteringResults)
# Out:
# Help on class UmapClusteringResults in module activ.clustering:
#
# class UmapClusteringResults(builtins.object)
#  |  Methods defined here:
#  |
#  |  __init__(self, results_path)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  adjust(self, op='mean')
#  |
#  |  make_heatmap(self, path=None, op='mean')
#  |      Make a heatmap. Save the heatmap to the specified path.
#  |      If *path* is not specified, save to *heatmap.png* in the
#  |      same directory as the given results file.
#  |
#  |      Args:
#  |          path        : the path to save the heatmap to
#  |          op          : the summary operation. options are 'median'
#  |                        or 'mean'. default is 'mean'
#  |
#  |  reshape(self, dat)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  path = UmapClusteringResultsPath(cluster_sizes='cluster...p_min_dist',...

# %%
results = UmapClusteringResults(path)
plt.figure(figsize=(15, 5))
ret = results.make_heatmap()
pdf.savefig()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-d840fd5bb8f8> in <module>()
#       2 plt.figure(figsize=(15, 5))
#       3 ret = results.make_heatmap()
# ----> 4 pdf.savefig()
#
# NameError: name 'pdf' is not defined

# %%
plt.figure(figsize=(12,8))
plt.title("Mean accuracy by cluster size across\nall iterations and dimension size")
plt.xlabel("Cluster sizes")
plt.ylabel("Fold over chance")
ret = plt.boxplot(results.adjust(), labels=results.cluster_sizes)
pdf.savefig()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-8936377587b5> in <module>()
#       4 plt.ylabel("Fold over chance")
#       5 ret = plt.boxplot(results.adjust(), labels=results.cluster_sizes)
# ----> 6 pdf.savefig()
#
# NameError: name 'pdf' is not defined

# %%
pdf.close()
