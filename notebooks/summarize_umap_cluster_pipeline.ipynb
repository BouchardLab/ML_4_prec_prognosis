# %% [markdown]
# # Summarize result of parameter sweep across UMAP dimension and Number of outcome clusters

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import h5py
import numpy as np
from activ.analytics import heatmap
from activ.clustering import UmapClusteringResults

def print_max(res, op='mean'):
    adj = res.adjust(op=op)
    ui, ci = np.unravel_index(np.argmax(adj, axis=None), adj.shape)
    print("max", op, ":", adj[ui, ci], '-', res.umap_dims[ui], "dimensions,", res.cluster_sizes[ci], "clusters")

# %%
results = UmapClusteringResults("../results/sweep_dims2-10_clus2-14/umap_clustering_sweep.h5")
results10_20 = UmapClusteringResults("../results/sweep_dims2-10_clus10-20/umap_clustering_sweep.h5")

# %% [markdown]
# ## UMAP dimensions: 2-10, Cluster sizes: 2-14

# %%
print_max(results)
ret = results.make_heatmap()
# Out:
# max mean : 1.6802363388026427 - 4 dimensions, 13 clusters

# %%
print_max(results, op='median')
ret = results.make_heatmap(op='median')
# Out:
# max median : 1.827827695560254 - 5 dimensions, 14 clusters

# %% [markdown]
# ## UMAP dimensions: 2-10, Cluster sizes: 10-20

# %%
print_max(results10_20)
ret = results10_20.make_heatmap()
# Out:
# max mean : 1.9238087938189508 - 5 dimensions, 20 clusters

# %%
print_max(results10_20, op='median')
ret = results10_20.make_heatmap(op='median')
# Out:
# max median : 2.0263381478334748 - 5 dimensions, 20 clusters

# %% [markdown]
# ## UMAP dimensions: 2-10, Cluster sizes: 2-25, predicted with outcome

# %%
results = UmapClusteringResults("../results/sweep_dims2-10_clus2-25_ocpred/umap_clustering_sweep.h5")

# %%
print_max(results)
ret = results.make_heatmap()
# Out:
# max mean : 12.462956565628435 - 2 dimensions, 25 clusters

# %%
print_max(results, op='median')
ret = results.make_heatmap(op='median')
# Out:
# max median : 13.333333333333332 - 8 dimensions, 25 clusters

# %%
y = results.chance_samples.mean(axis=3).mean(axis=0).mean(axis=0)
x = np.arange(2,26)
plt.scatter(x,y)
plt.scatter(x, 1/x)

# %%
dir(results)
# Out:
# ['_UmapClusteringResults__acc',
#  '_UmapClusteringResults__chance',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'acc_samples',
#  'adjust',
#  'chance_samples',
#  'cluster_sizes',
#  'clusters',
#  'make_heatmap',
#  'outdir',
#  'path',
#  'reshape',
#  'umap_dims']

# %%
results.clusters.shape
# Out:
# (50, 9, 24, 247)
